# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm
import statsmodels.api as sm
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
try:
    anscombe_df = pd.read_csv("Anscombe.csv")
except:
    anscombe_df = pd.read_csv("http://vincentarelbundock.github.io/Rdatasets/csv/carData/Anscombe.csv")
    anscombe_df.to_csv("Anscombe.csv")

# %%
anscombe_df.head()
# Out:
#    Unnamed: 0 Unnamed: 0.1  education  income  young  urban
# 0           0           ME        189    2824  350.7    508
# 1           1           NH        169    3259  345.9    564
# 2           2           VT        230    3072  348.5    322
# 3           3           MA        168    3835  335.3    846
# 4           4           RI        180    3549  327.1    871

# %%
_ = pd.plotting.scatter_matrix(anscombe_df, diagonal="hist", figsize=(10,10))

# %%
y = anscombe_df["education"].values

x1 = anscombe_df["income"].values
x2 = anscombe_df["young"].values
x3 = anscombe_df["urban"].values
X = np.vstack((np.ones(x1.shape[0]), x1, x2, x3)).T

X.shape, y.shape
# Out:
# ((51, 4), (51,))

# %%
model_1 = sm.OLS(y, X).fit()
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.670
# Method:                 Least Squares   F-statistic:                     34.81
# Date:                Thu, 27 Feb 2020   Prob (F-statistic):           5.34e-12
# Time:                        19:23:36   Log-Likelihood:                -237.79
# No. Observations:                  51   AIC:                             483.6
# Df Residuals:                      47   BIC:                             491.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -286.8388     64.920     -4.418      0.000    -417.441    -156.237
# ...

# %% [markdown]
# ```
# library("rjags")
#
# mod_string = " model {
#     for (i in 1:length(education)) {
#         education[i] ~ dnorm(mu[i], prec)
#         mu[i] = b0 + b[1]*income[i] + b[2]*young[i] + b[3]*urban[i]
#     }
#
#     b0 ~ dnorm(0.0, 1.0/1.0e6)
#     for (i in 1:3) {
#         b[i] ~ dnorm(0.0, 1.0/1.0e6)
#     }
#
#     prec ~ dgamma(1.0/2.0, 1.0*1500.0/2.0)
#     	## Initial guess of variance based on overall
#     	## variance of education variable. Uses low prior
#     	## effective sample size. Technically, this is not
#     	## a true 'prior', but it is not very informative.
#     sig2 = 1.0 / prec
#     sig = sqrt(sig2)
# } "
#
# data_jags = as.list(Anscombe)
# ```

# %%
with pm.Model() as linreg_model:
    betas = pm.Normal("betas", mu=0, sigma=1e-6, shape=4)
#     sigma2 = pm.InverseGamma("sigma2", alpha=0.5, beta=0.01)
    sigma2 = pm.Normal("sigma2", mu=0, sigma=1)

    sigma = np.sqrt(sigma2)
    mu = betas[0] + betas[1] * x1 + betas[2] * x2 + betas[3] * x3
    
    y_obs = pm.Normal("y_obs", mu=mu, sigma=sigma, observed=y)
    trace = pm.sample(5000, tune=1000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma2, betas]
# Sampling 4 chains, 0 divergences:   4%|▍         | 1016/24000 [00:13<04:54, 78.00draws/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/palsujit/anaconda3/envs/bayes/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 110, in run
#     self._start_loop()
#   File "/Users/palsujit/anaconda3/envs/bayes/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 160, in _start_loop
#     point, stats = self._compute_point()
#   File "/Users/palsujit/anaconda3/envs/bayes/lib/python3.8/site-packages/pymc3/parallel_sampling.py", line 191, in _compute_point
#     point, stats = self._step_method.step(self._point)
# ...

# %%
pm.traceplot(trace, combined=True)
